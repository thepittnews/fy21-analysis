# %% [markdown]
# # Setup

# %%
import pandas as pd

TRANSACTION_INDEX = 'TPN_ID'

# %% [markdown]
# # Open data files

# %%
original = pd.read_csv("./data/original_sorted.csv")

# %%
original.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5568 entries, 0 to 5567
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RC#          5568 non-null   int64
#  1   RC Name      5568 non-null   object
#  2   Category     5568 non-null   int64
#  3   Vendor#      5568 non-null   int64
#  4   Vendor Name  5568 non-null   object
#  5   Address 1    5544 non-null   object
#  6   Address 2    1290 non-null   object
#  7   City         5469 non-null   object
#  8   State        5371 non-null   object
#  9   ZIP code     5557 non-null   object
#  10  Amount       5568 non-null   int64
#  11  TPN_ID       5568 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 522.1+ KB

# %%
updated = pd.read_csv("./data/updated_sorted.csv")

# %%
updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5920 entries, 0 to 5919
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   RC#          5920 non-null   int64
#  1   RC Name      5920 non-null   object
#  2   Category     5920 non-null   int64
#  3   Vendor#      5920 non-null   int64
#  4   Vendor Name  5920 non-null   object
#  5   Address 1    5896 non-null   object
#  6   Address 2    1359 non-null   object
#  7   City         5821 non-null   object
#  8   State        5716 non-null   object
#  9   ZIP code     5909 non-null   object
#  10  Amount       5920 non-null   int64
#  11  TPN_ID       5920 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 555.1+ KB

# %% [markdown]
# # Top-line numbers

# %%
original_sum = original.Amount.sum()
updated_sum = updated.Amount.sum()
updated_sum - original_sum
# Out:
# 30599050

# %%
(updated_sum - original_sum)/original_sum
# Out:
# 0.08429766752297206

# %%
new_transactions = len(updated.index.unique()) - len(original.index.unique())
new_transactions
# Out:
# 352

# %% [markdown]
# # Merge transactions

# %%
merged_transactions = original.merge(updated, on=TRANSACTION_INDEX, suffixes=('_o', '_u'))
merged_transactions['AmountDiff'] = merged_transactions.Amount_u - merged_transactions.Amount_o

# %% [markdown]
# # Largest amounts - change from original to updated

# %%
merged_transactions.sort_values(by=['AmountDiff'], ascending=False).head(5)
# Out:
#       RC#_o                        RC Name_o  Category_o  Vendor#_o  \
# 4768     85              SOMD Administration        7300     424204
# 5304     92  Business and Auxiliary Services        7300     505445
# 4414     83               General University        7700     204776
# 5310     92  Business and Auxiliary Services        7300     687995
# 3799     67            Facilities Management        7000     103658
#
#                              Vendor Name_o  \
# 4768                            BPA II LTD
# 5304  WYNDHAM PITTSBURGH UNIVERSITY CENTER
# 4414                        MARSH USA, INC
# 5310                     MWK FORBES II LLC
# 3799                DUQUESNE LIGHT COMPANY
#
#                                 Address 1_o Address 2_o      City_o State_o  \
# 4768         1468 WEST 9TH STREET SUITE 835         NaN   CLEVELAND      OH
# 5304  545 E JOHN CARPENTER FREEWAY STE 1300         NaN      IRVING      TX
# 4414                         P O BOX 281915         NaN     ATLANTA      GA
# 5310                     3341 FORBES AVENUE         NaN  PITTSBURGH      PA
# 3799                          PO BOX 830012         NaN   BALTIMORE      MD
#
#       ZIP code_o  ...  Category_u Vendor#_u  \
# 4768       44113  ...        7300    424204
# 5304       75062  ...        7300    505445
# 4414       30384  ...        7700    204776
# 5310       15213  ...        7300    687995
# 3799  21283-0012  ...        7000    103658
#
#                              Vendor Name_u  \
# 4768                            BPA II LTD
# 5304  WYNDHAM PITTSBURGH UNIVERSITY CENTER
# 4414                        MARSH USA, INC
# 5310                     MWK FORBES II LLC
# 3799                DUQUESNE LIGHT COMPANY
#
#                                 Address 1_u  Address 2_u      City_u State_u  \
# 4768         1468 WEST 9TH STREET SUITE 835          NaN   CLEVELAND      OH
# 5304  545 E JOHN CARPENTER FREEWAY STE 1300          NaN      IRVING      TX
# 4414                         P O BOX 281915          NaN     ATLANTA      GA
# 5310                     3341 FORBES AVENUE          NaN  PITTSBURGH      PA
# 3799                          PO BOX 830012          NaN   BALTIMORE      MD
#
#       ZIP code_u  Amount_u AmountDiff
# 4768       44113  10951439    2584599
# 5304       75062  11657790    2023060
# 4414       30384   6071082    1735802
# 5310       15213   6280388    1112046
# 3799  21283-0012  24578216     747194
#
# [5 rows x 24 columns]

# %% [markdown]
# # Amounts - change from original to updated

# %%
merged_transactions[merged_transactions['AmountDiff'] < 0].sort_values(by=['AmountDiff'], ascending=True)
# Out:
#       RC#_o                                        RC Name_o  Category_o  \
# 39        1                                       Chancellor        6400
# 167       3                                     SVC Research        6400
# 1938     35                               School of Medicine        7100
# 3558     61                      Pitt Information Technology        7400
# 5541     94              School of Computing and Information        6000
# 921      22                              School of Education        6400
# 418       6  Kenneth P. Dietrich School of Arts and Sciences        6000
# 428       6  Kenneth P. Dietrich School of Arts and Sciences        6000
# 4178     80                                        Athletics        6000
# 11        1                                       Chancellor        6000
# 2296     41                                 Johnstown Campus        7100
# 4787     87                  SVC and Chief Financial Officer        6000
# 2261     41                                 Johnstown Campus        7000
# 2589     44                                  Bradford Campus        6000
#
#       Vendor#_o                           Vendor Name_o  \
# 39       320609                              MEDIAQUEST
# 167      424663                      CPA GLOBAL LIMITED
# 1938     100897                   AQUA FILTER FRESH INC
# 3558     482143                        COMCAST BUSINESS
# 5541     100877                      APPLE COMPUTER INC
# 921      500751                             INRESONANCE
# 418      503874               SAI LIFE SCIENCES LIMITED
# 428      555151                             LABWEAR.COM
# 4178     675887  KINETIC PERFORMANCE TECHNOLOGY PTY LTD
# 11       521322              SUPRA OFFICE SOLUTIONS INC
# 2296     390128                          PENSTAN SUPPLY
# 4787     521322              SUPRA OFFICE SOLUTIONS INC
# 2261     271651                                 PENELEC
# 2589     311515                  BISETT BUILDING CENTER
#
#                                    Address 1_o  \
# 39                       4891 CAMPBELLS RUN RD
# 167                         225 REINEKERS LANE
# 1938                              PO BOX 14128
# 3558                ONE COMCAST CENTER 32ND FL
# 5541                             PO BOX 281877
# 921                   32 INDUSTRIAL DRIVE EAST
# 418   GROUND 1ST 2ND & 3RD FL BLDG I PLOT NO 2
# 428         480 BARNUM AVE BUILDING 5 SUITE 30
# 4178                UNIT 8 26-28 WINCHCOMBE CT
# 11                                  PO BOX 201
# 2296                         850 HORNER STREET
# 4787                                PO BOX 201
# 2261                               PO BOX 3687
# 2589                                PO BOX 196
#
#                               Address 2_o        City_o State_o  ZIP code_o  \
# 39                                    NaN    PITTSBURGH      PA       15205
# 167                              STE. 400    ALEXANDRIA      VA       22314
# 1938                                  NaN    PITTSBURGH      PA  15239-0128
# 3558                                  NaN  PHILADELPHIA      PA  19103-2838
# 5541                                  NaN       ATLANTA      GA  30384-1877
# 921                               SUITE 1   NORTHAMPTON      MA       01060
# 418   CHRYSALIS ENCLAVE INTL BIOTECH PARK     HINJEWADI    PUNE     411 057
# 428                                   NaN    BRIDGEPORT      CT       06608
# 4178                                  NaN  MITCHELL ACT     NaN        2911
# 11                                    NaN   BALA CYNWYD      PA       19004
# 2296                                  NaN     JOHNSTOWN      PA       15902
# 4787                                  NaN   BALA CYNWYD      PA       19004
# 2261                                  NaN         AKRON      OH  44309-3687
# 2589                                  NaN      BRADFORD      PA       16701
#
#       ...  Category_u Vendor#_u                           Vendor Name_u  \
# 39    ...        6400    320609                              MEDIAQUEST
# 167   ...        6400    424663                      CPA GLOBAL LIMITED
# 1938  ...        7100    100897                   AQUA FILTER FRESH INC
# 3558  ...        7400    482143                        COMCAST BUSINESS
# 5541  ...        6000    100877                      APPLE COMPUTER INC
# 921   ...        6400    500751                             INRESONANCE
# 418   ...        6000    503874               SAI LIFE SCIENCES LIMITED
# 428   ...        6000    555151                             LABWEAR.COM
# 4178  ...        6000    675887  KINETIC PERFORMANCE TECHNOLOGY PTY LTD
# 11    ...        6000    521322              SUPRA OFFICE SOLUTIONS INC
# 2296  ...        7100    390128                          PENSTAN SUPPLY
# 4787  ...        6000    521322              SUPRA OFFICE SOLUTIONS INC
# 2261  ...        7000    271651                                 PENELEC
# 2589  ...        6000    311515                  BISETT BUILDING CENTER
#
#                                    Address 1_u  \
# 39                       4891 CAMPBELLS RUN RD
# 167                         225 REINEKERS LANE
# 1938                              PO BOX 14128
# 3558                ONE COMCAST CENTER 32ND FL
# 5541                             PO BOX 281877
# 921                              PO BOX 122145
# 418   GROUND 1ST 2ND & 3RD FL BLDG I PLOT NO 2
# 428         480 BARNUM AVE BUILDING 5 SUITE 30
# 4178                UNIT 8 26-28 WINCHCOMBE CT
# 11                                  PO BOX 201
# 2296                         850 HORNER STREET
# 4787                                PO BOX 201
# 2261                               PO BOX 3687
# 2589                                PO BOX 196
#
#                               Address 2_u        City_u State_u  ZIP code_u  \
# 39                                    NaN    PITTSBURGH      PA       15205
# 167                              STE. 400    ALEXANDRIA      VA       22314
# 1938                                  NaN    PITTSBURGH      PA  15239-0128
# 3558                                  NaN  PHILADELPHIA      PA  19103-2838
# 5541                                  NaN       ATLANTA      GA  30384-1877
# 921                             DEPT 2145        DALLAS      TX  75312-2145
# 418   CHRYSALIS ENCLAVE INTL BIOTECH PARK     HINJEWADI    PUNE     411 057
# 428                                   NaN    BRIDGEPORT      CT       06608
# 4178                                  NaN  MITCHELL ACT     NaN        2911
# 11                                    NaN   BALA CYNWYD      PA       19004
# 2296                                  NaN     JOHNSTOWN      PA       15902
# 4787                                  NaN   BALA CYNWYD      PA       19004
# 2261                                  NaN         AKRON      OH  44309-3687
# 2589                                  NaN      BRADFORD      PA       16701
#
#      Amount_u AmountDiff
# 39      23212     -27455
# 167    927936      -9364
# 1938     4213      -5836
# 3558    40233      -3773
# 5541    13142      -2142
# 921     64907      -1840
# 418     19355      -1155
# 428      1685       -727
# 4178    17163       -555
# 11       6302       -298
# 2296    24085       -188
# 4787    10895        -71
# 2261  1001221        -55
# 2589     4888        -23
#
# [14 rows x 24 columns]

# %%
merged_transactions[merged_transactions['AmountDiff'] == 0]
# Out:
#       RC#_o                            RC Name_o  Category_o  Vendor#_o  \
# 0         1                           Chancellor        6000     100877
# 1         1                           Chancellor        6000     101243
# 3         1                           Chancellor        6000     104384
# 4         1                           Chancellor        6000     119301
# 6         1                           Chancellor        6000     223247
# ...     ...                                  ...         ...        ...
# 5557     94  School of Computing and Information        6400     509937
# 5558     94  School of Computing and Information        6400     562181
# 5559     94  School of Computing and Information        6400     588965
# 5560     94  School of Computing and Information        6400     687570
# 5561     94  School of Computing and Information        6900     328199
#
#                                 Vendor Name_o                     Address 1_o  \
# 0                          APPLE COMPUTER INC                   PO BOX 281877
# 1                             B&H PHOTO VIDEO            119 WEST 17TH STREET
# 3                          FRANKLIN INTERIORS                     PO BOX 6107
# 4                               WORKSCAPE INC             KNOLL C/O WORKSCAPE
# 6                  GEORGIA TECH RESEARCH CORP                   PO BOX 100117
# ...                                       ...                             ...
# 5557                                 GO-U LLC               2310 RIDGE AVENUE
# 5558                           ADAM REGER LLC                 409 EMERSON AVE
# 5559                                 EMMA INC  75 REMITTANCE DRIVE SUITE 6222
# 5560                THOMAS, JAMES           5            2910 N VAN NESS BLVD
# 5561  ASSOCIATION FOR LIBRARY AND INFORMATION           39349 TREASURY CENTER
#
#         Address 2_o      City_o State_o  ZIP code_o  ...  Category_u  \
# 0               NaN     ATLANTA      GA  30384-1877  ...        6000
# 1               NaN    NEW YORK      NY       10011  ...        6000
# 3               NaN   HERMITAGE      PA  16148-0923  ...        6000
# 4     PO BOX 277778     ATLANTA      GA  30384-7778  ...        6000
# 6               NaN     ATLANTA      GA       30384  ...        6000
# ...             ...         ...     ...         ...  ...         ...
# 5557            NaN    EVANSTON      IL       60201  ...        6400
# 5558            NaN  PITTSBURGH      PA       15215  ...        6400
# 5559            NaN     CHICAGO      IL  60675-6222  ...        6400
# 5560            NaN      FRESNO      CA       93704  ...        6400
# 5561            NaN     CHICAGO      IL  60694-9300  ...        6900
#
#      Vendor#_u                            Vendor Name_u  \
# 0       100877                       APPLE COMPUTER INC
# 1       101243                          B&H PHOTO VIDEO
# 3       104384                       FRANKLIN INTERIORS
# 4       119301                            WORKSCAPE INC
# 6       223247               GEORGIA TECH RESEARCH CORP
# ...        ...                                      ...
# 5557    509937                                 GO-U LLC
# 5558    562181                           ADAM REGER LLC
# 5559    588965                                 EMMA INC
# 5560    687570                THOMAS, JAMES           5
# 5561    328199  ASSOCIATION FOR LIBRARY AND INFORMATION
#
#                          Address 1_u    Address 2_u      City_u State_u  \
# 0                      PO BOX 281877            NaN     ATLANTA      GA
# 1               119 WEST 17TH STREET            NaN    NEW YORK      NY
# 3                        PO BOX 6107            NaN   HERMITAGE      PA
# 4                KNOLL C/O WORKSCAPE  PO BOX 277778     ATLANTA      GA
# 6                      PO BOX 100117            NaN     ATLANTA      GA
# ...                              ...            ...         ...     ...
# 5557               2310 RIDGE AVENUE            NaN    EVANSTON      IL
# 5558                 409 EMERSON AVE            NaN  PITTSBURGH      PA
# 5559  75 REMITTANCE DRIVE SUITE 6222            NaN     CHICAGO      IL
# 5560            2910 N VAN NESS BLVD            NaN      FRESNO      CA
# 5561           39349 TREASURY CENTER            NaN     CHICAGO      IL
#
#       ZIP code_u Amount_u AmountDiff
# 0     30384-1877    18071          0
# 1          10011     4019          0
# 3     16148-0923     3284          0
# 4     30384-7778     2051          0
# 6          30384     5120          0
# ...          ...      ...        ...
# 5557       60201     8000          0
# 5558       15215     2000          0
# 5559  60675-6222     2868          0
# 5560       93704     1999          0
# 5561  60694-9300     2300          0
#
# [5309 rows x 24 columns]

# %%
merged_transactions[merged_transactions['AmountDiff'] > 0].sort_values(by=['AmountDiff'], ascending=False)
# Out:
#       RC#_o                        RC Name_o  Category_o  Vendor#_o  \
# 4768     85              SOMD Administration        7300     424204
# 5304     92  Business and Auxiliary Services        7300     505445
# 4414     83               General University        7700     204776
# 5310     92  Business and Auxiliary Services        7300     687995
# 3799     67            Facilities Management        7000     103658
# ...     ...                              ...         ...        ...
# 2177     41                 Johnstown Campus        6000     248635
# 4621     85              SOMD Administration        6600     534443
# 5         1                       Chancellor        6000     185133
# 214       5                  Student Affairs        6000     100877
# 3591     67            Facilities Management        6000     107557
#
#                              Vendor Name_o  \
# 4768                            BPA II LTD
# 5304  WYNDHAM PITTSBURGH UNIVERSITY CENTER
# 4414                        MARSH USA, INC
# 5310                     MWK FORBES II LLC
# 3799                DUQUESNE LIGHT COMPANY
# ...                                    ...
# 2177                              GRAINGER
# 4621                             SPOK, INC
# 5                       CDW GOVERNMENT INC
# 214                     APPLE COMPUTER INC
# 3591             MICROBAC LABORATORIES INC
#
#                                 Address 1_o Address 2_o      City_o State_o  \
# 4768         1468 WEST 9TH STREET SUITE 835         NaN   CLEVELAND      OH
# 5304  545 E JOHN CARPENTER FREEWAY STE 1300         NaN      IRVING      TX
# 4414                         P O BOX 281915         NaN     ATLANTA      GA
# 5310                     3341 FORBES AVENUE         NaN  PITTSBURGH      PA
# 3799                          PO BOX 830012         NaN   BALTIMORE      MD
# ...                                     ...         ...         ...     ...
# 2177                    3750 BROOKSIDE PKWY     STE 260  ALPHARETTA      GA
# 4621        5911 KINGSTOWNE VILLAGE PARKWAY   6TH FLOOR  ALEXANDRIA      VA
# 5                          75 REMITTANCE DR  SUITE 1515     CHICAGO      IL
# 214                           PO BOX 281877         NaN     ATLANTA      GA
# 3591          4750 NAUTILUS CT SOUTH UNIT A         NaN     BOULDER      CO
#
#       ZIP code_o  ...  Category_u Vendor#_u  \
# 4768       44113  ...        7300    424204
# 5304       75062  ...        7300    505445
# 4414       30384  ...        7700    204776
# 5310       15213  ...        7300    687995
# 3799  21283-0012  ...        7000    103658
# ...          ...  ...         ...       ...
# 2177  30022-1433  ...        6000    248635
# 4621       22315  ...        6600    534443
# 5     60675-1515  ...        6000    185133
# 214   30384-1877  ...        6000    100877
# 3591       80301  ...        6000    107557
#
#                              Vendor Name_u  \
# 4768                            BPA II LTD
# 5304  WYNDHAM PITTSBURGH UNIVERSITY CENTER
# 4414                        MARSH USA, INC
# 5310                     MWK FORBES II LLC
# 3799                DUQUESNE LIGHT COMPANY
# ...                                    ...
# 2177                              GRAINGER
# 4621                             SPOK, INC
# 5                       CDW GOVERNMENT INC
# 214                     APPLE COMPUTER INC
# 3591             MICROBAC LABORATORIES INC
#
#                                 Address 1_u  Address 2_u      City_u State_u  \
# 4768         1468 WEST 9TH STREET SUITE 835          NaN   CLEVELAND      OH
# 5304  545 E JOHN CARPENTER FREEWAY STE 1300          NaN      IRVING      TX
# 4414                         P O BOX 281915          NaN     ATLANTA      GA
# 5310                     3341 FORBES AVENUE          NaN  PITTSBURGH      PA
# 3799                          PO BOX 830012          NaN   BALTIMORE      MD
# ...                                     ...          ...         ...     ...
# 2177                    3750 BROOKSIDE PKWY      STE 260  ALPHARETTA      GA
# 4621        5911 KINGSTOWNE VILLAGE PARKWAY    6TH FLOOR  ALEXANDRIA      VA
# 5                          75 REMITTANCE DR   SUITE 1515     CHICAGO      IL
# 214                           PO BOX 281877          NaN     ATLANTA      GA
# 3591          4750 NAUTILUS CT SOUTH UNIT A          NaN     BOULDER      CO
#
#       ZIP code_u  Amount_u AmountDiff
# 4768       44113  10951439    2584599
# 5304       75062  11657790    2023060
# 4414       30384   6071082    1735802
# 5310       15213   6280388    1112046
# 3799  21283-0012  24578216     747194
# ...          ...       ...        ...
# 2177  30022-1433    125297         53
# 4621       22315      8301         53
# 5     60675-1515      7547         47
# 214   30384-1877     18835         38
# 3591       80301      1233         19
#
# [239 rows x 24 columns]

# %% [markdown]
# # Largest amounts - only appearing in updated

# %%
new_transactions = original.merge(updated.drop_duplicates(), on=TRANSACTION_INDEX, how='right', indicator=True)
new_transactions.fillna(value={"Amount_x": 0}, inplace=True)
new_transactions['AmountDiff'] = new_transactions.Amount_y - new_transactions.Amount_x

# %%
display_columns = ['RC#_y', 'RC Name_y', 'Category_y', 'Vendor#_y', 'Vendor Name_y', 'Address 1_y', 'Address 2_y', 'City_y', 'State_y', 'ZIP code_y', 'Amount_y', 'TPN_ID', '_merge', 'AmountDiff']
new_transactions[new_transactions._merge == "right_only"].sort_values(by=['AmountDiff'], ascending=False).head(5)[display_columns]
# Out:
#       RC#_y                                        RC Name_y  Category_y  \
# 469       6  Kenneth P. Dietrich School of Arts and Sciences        6400
# 5861     93           Public Safety and Emergency Management        6400
# 1315     30                              SVC Health Sciences        6400
# 787      10                                  SVC and Provost        6400
# 5063     87                  SVC and Chief Financial Officer        6400
#
#       Vendor#_y                          Vendor Name_y  \
# 469      104257          FISHER SCIENTIFIC COMPANY LLC
# 5861     446194  LANDMARK EVENT STAFFING SERVICES, INC
# 1315     114200                      QUEST DIAGNOSTICS
# 787      689608                                    PFL
# 5063     521322             SUPRA OFFICE SOLUTIONS INC
#
#                  Address 1_y Address 2_y        City_y State_y  ZIP code_y  \
# 469            PO BOX 406538         NaN       ATLANTA      GA  30384-6538
# 5861  4131 HARBOR WALK DRIVE         NaN  FORT COLLINS      CO       80525
# 1315         P.O. BOX 740709         NaN       ATLANTA      GA  30374-0709
# 787              100 PFL WAY         NaN    LIVINGSTON      MT       59047
# 5063              PO BOX 201         NaN   BALA CYNWYD      PA       19004
#
#       Amount_y          TPN_ID      _merge  AmountDiff
# 469    2344352   6-6400-104257  right_only   2344352.0
# 5861   1689115  93-6400-446194  right_only   1689115.0
# 1315   1237840  30-6400-114200  right_only   1237840.0
# 787     790510  10-6400-689608  right_only    790510.0
# 5063    600681  87-6400-521322  right_only    600681.0
